# %% [markdown]
# # Import libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Images

# %%
img1=cv2.imread('C:\MY DRIVE\Material\Digital Image Processing\Image database\DIP3E_CH03_Original_Images\DIP3E_Original_Images_CH03/Fig0316(1)(top_left).tif',0)
img2=cv2.imread('C:\MY DRIVE\Material\Digital Image Processing\Image database\DIP3E_CH03_Original_Images\DIP3E_Original_Images_CH03/Fig0316(2)(2nd_from_top).tif',0)
img3=cv2.imread('C:\MY DRIVE\Material\Digital Image Processing\Image database\DIP3E_CH03_Original_Images\DIP3E_Original_Images_CH03/Fig0316(4)(bottom_left).tif',0)
img4=cv2.imread('C:\MY DRIVE\Material\Digital Image Processing\Image database\DIP3E_CH03_Original_Images\DIP3E_Original_Images_CH03/Fig0316(3)(third_from_top).tif',0)

# %%
img1.shape
# Out:
# (500, 500)

# %%
plt.imshow(img1,cmap='gray')

# %%
img1_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(img1_rgb)

# %%
img1_rgb.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(img1,cmap='gray')

# %% [markdown]
# # Take all image pixel in one array
# flatten function make multidimension arrary to 1D

# %%
flat_img1=img1.flatten()

# %%
flat_img1.shape
# Out:
# (250000,)

# %%
# Plot Histogram of the image

# %%
plt.hist(flat_img1)
# Out:
# (array([29511., 37574., 11127., 16658., 18248., 23857., 23394., 26366.,
#         22446., 40819.]),
#  array([132. , 144.3, 156.6, 168.9, 181.2, 193.5, 205.8, 218.1, 230.4,
#         242.7, 255. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Check range of the image
# Continue the same things for four different images

# %%
print('Range:',flat_img1.max()-flat_img1.min())
# Out:
# Range: 123

# %%
img2_rgb=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img2_rgb)

# %% [markdown]
# # light image's histogram is close to 255

# %%
flat_img2=img2.flatten()
plt.hist(flat_img2)
# Out:
# (array([30392., 42297., 28487., 22708., 42177., 32745., 23287., 14804.,
#         10696.,  2407.]),
#  array([ 91. ,  95.7, 100.4, 105.1, 109.8, 114.5, 119.2, 123.9, 128.6,
#         133.3, 138. ]),
#  <BarContainer object of 10 artists>)

# %%
print('Range:',flat_img2.max()-flat_img2.min())
# Out:
# Range: 47

# %%
img3_rgb=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img3_rgb)

# %% [markdown]
# # Dark image histogram bars are close to zero

# %%
flat_img3=img3.flatten()
plt.hist(flat_img3)
# Out:
# (array([47610., 30602., 22964., 31888., 37249., 27256., 24524., 15289.,
#         10557.,  2061.]),
#  array([13., 20., 27., 34., 41., 48., 55., 62., 69., 76., 83.]),
#  <BarContainer object of 10 artists>)

# %%
img4_rgb=cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)
plt.imshow(img4_rgb)

# %% [markdown]
# # High contrast image' histogram cover entire range

# %%
flat_img4=img4.flatten()
plt.hist(flat_img4)
# Out:
# (array([34923., 37199., 17943., 21609., 26726., 29061., 27765., 20402.,
#         15495., 18877.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
