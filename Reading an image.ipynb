# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Read image using imread funtion of cv2 package

# %%
img=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/image3.png',1)

# %%
print(img)
# Out:
# [[[ 23  23  23]
#   [ 30  30  30]
#   [ 32  32  32]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[ 38  38  38]
#   [ 26  26  26]
#   [ 39  39  39]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[ 35  35  35]
#   [ 21  21  21]
#   [ 43  43  43]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  ...
#
#  [[ 31  31  31]
#   [ 31  31  31]
#   [ 29  29  29]
#   ...
#   [ 30  30  30]
#   [ 30  30  30]
#   [ 30  30  30]]
#
#  [[ 31  31  31]
#   [ 31  31  31]
#   [ 29  29  29]
#   ...
#   [ 30  30  30]
#   [ 30  30  30]
#   [ 30  30  30]]
#
#  [[ 31  31  31]
#   [ 31  31  31]
#   [ 29  29  29]
#   ...
#   [ 30  30  30]
#   [ 30  30  30]
#   [ 30  30  30]]]

# %%
# Display image using matplotlib

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (571, 482)

# %% [markdown]
# # Display image using cv2

# %%
#cv2.imshow('original',img)
#cv2.waitKey()

# %%
img1=cv2.resize(img,(1024,1024))

# %%
plt.imshow(img1)

# %%
print(img1.shape)
# Out:
# (1024, 1024)

# %%
img1=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/image3.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img1, cmap='gray')

# %%
img1.shape
# Out:
# (571, 482)

# %%
cv2.imwrite('Saved_image.png',img1)
# Out:
# True

# %%
img1=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/leena.jpeg',1)

# %%
plt.imshow(img1)

# %%
img1.size
# Out:
# 151875

# %%
img1.shape
# Out:
# (225, 225, 3)

# %%
#print(img1)

# %% [markdown]
# # Convert image to RGB

# %%
img1_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(img1_rgb)

# %%
img1_gray=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/leena.jpeg',0)

# %%
ax1=plt.subplot(1,3,1)
plt.title('image in BGR')
plt.imshow(img1)
ax1=plt.subplot(1,3,2)
plt.title('image in RGB')
plt.imshow(img1_rgb)
ax1=plt.subplot(1,3,3)
plt.title('image in Gray scale')
plt.imshow(img1_gray,cmap='gray')

# %% [markdown]
# # Splitting an image into its channels

# %%
img=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/Fig0316(3)(third_from_top).tif',1)

# %%
plt.imshow(img)
