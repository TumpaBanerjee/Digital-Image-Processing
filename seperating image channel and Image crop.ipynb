# %% [markdown]
# # Import libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read a color image

# %% [markdown]
# # Read the image

# %%
img1=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/leena.jpeg',1)

# %% [markdown]
# # Show the image

# %%
plt.imshow(img1)

# %% [markdown]
# # Image read in BGR format in Python.
# Convert the image BGR to RGB

# %%
img_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
img1.shape
# Out:
# (225, 225, 3)

# %% [markdown]
# # Printing single channel at a time

# %%
print("Individual channel of BGR Image")
ax1=plt.subplot(1,3,1)
plt.title('Blue')
plt.imshow(img1[:,:,0])

ax1=plt.subplot(1,3,2)
plt.title('Green')
plt.imshow(img1[:,:,1])

ax1=plt.subplot(1,3,3)
plt.title('Red')
plt.imshow(img1[:,:,2])
# Out:
# Individual channel of BGR Image

# %%
ax1=plt.subplot(1,3,1)
plt.title('Red')
plt.imshow(img_rgb[:,:,0])
ax1=plt.subplot(1,3,2)
plt.title('Green')
plt.imshow(img_rgb[:,:,1])
ax1=plt.subplot(1,3,3)
plt.title('Blue')
plt.imshow(img_rgb[:,:,2])

# %%
# Printing image in Reb, Green, and Blue channel only by putting zeor for remianing two channel

# %%
r=img_rgb.copy()
r[:,:,0]=0
r[:,:,1]=0
ax1=plt.subplot(1,3,1)
plt.title('Blue')
print('BlueChannel')
plt.imshow(r)
r=img_rgb.copy()
r[:,:,0]=0
r[:,:,2]=0
ax1=plt.subplot(1,3,2)
plt.title('Green')
print('Green Channel')
plt.imshow(r)
r=img_rgb.copy()
r[:,:,2]=0
r[:,:,1]=0
ax1=plt.subplot(1,3,3)
plt.title('Red')
print('Red Channel')
plt.imshow(r)
# Out:
# BlueChannel
# Green Channel
# Red Channel

# %%
plt.imshow(r)

# %%
img1=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/Fig0316(3)(third_from_top).tif',1)

# %%
plt.imshow(img1)

# %%
img_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
ax1=plt.subplot(1,3,1)
plt.title('Red')
plt.imshow(img_rgb[:,:,0])
ax1=plt.subplot(1,3,2)
plt.title('Green')
plt.imshow(img_rgb[:,:,1])
ax1=plt.subplot(1,3,3)
plt.title('Blue')
plt.imshow(img_rgb[:,:,2])

# %%
r=img_rgb.copy()
r[:,:,0]=0
r[:,:,1]=0
ax1=plt.subplot(1,3,1)
plt.title('Blue')
print('BlueChannel')
plt.imshow(r)
r=img_rgb.copy()
r[:,:,0]=0
r[:,:,2]=0
ax1=plt.subplot(1,3,2)
plt.title('Green')
print('Green Channel')
plt.imshow(r)
r=img_rgb.copy()
r[:,:,2]=0
r[:,:,1]=0
ax1=plt.subplot(1,3,3)
plt.title('Red')
print('Red Channel')
plt.imshow(r)
# Out:
# BlueChannel
# Green Channel
# Red Channel

# %%
r=img_rgb.copy()
r.shape
# Out:
# (500, 500, 3)

# %% [markdown]
# # Crop the image

# %%
r1=r[200:401,200:401,:]
plt.imshow(r1)

# %%
r1=r[350:401,350:401,:]
plt.imshow(r1)

# %%
print(r1)
print(r1.shape)
# Out:
# [[[154 154 154]
#   [166 166 166]
#   [140 140 140]
#   ...
#   [ 25  25  25]
#   [ 18  18  18]
#   [ 15  15  15]]
#
#  [[140 140 140]
#   [146 146 146]
#   [133 133 133]
#   ...
#   [ 25  25  25]
#   [ 18  18  18]
#   [ 19  19  19]]
#
#  [[142 142 142]
#   [148 148 148]
#   [157 157 157]
#   ...
#   [ 25  25  25]
#   [ 18  18  18]
#   [ 24  24  24]]
#
#  ...
#
#  [[127 127 127]
#   [105 105 105]
#   [105 105 105]
#   ...
#   [ 29  29  29]
#   [ 29  29  29]
#   [ 15  15  15]]
#
#  [[135 135 135]
#   [127 127 127]
#   [122 122 122]
#   ...
#   [ 16  16  16]
#   [ 11  11  11]
#   [ 16  16  16]]
#
#  [[126 126 126]
#   [126 126 126]
#   [116 116 116]
#   ...
#   [ 11  11  11]
#   [  2   2   2]
#   [ 18  18  18]]]
# (51, 51, 3)

# %%
r2=r1[:,:,0]
print(r2)
print(r2.shape)
# Out:
# [[154 166 140 ...  25  18  15]
#  [140 146 133 ...  25  18  19]
#  [142 148 157 ...  25  18  24]
#  ...
#  [127 105 105 ...  29  29  15]
#  [135 127 122 ...  16  11  16]
#  [126 126 116 ...  11   2  18]]
# (51, 51)

# %% [markdown]
# # Print pixel value of a particular location for each channel

# %%
img_rgb[100,100,0]
# Out:
# 163

# %%
r=img_rgb.copy()
r[:,:,2]=0
r[:,:,1]=0
r[100,100,0]
# Out:
# 163

# %%
img1=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/Fig0316(3)(third_from_top).tif',1)

# %%
img1.shape
# Out:
# (500, 500, 3)

# %% [markdown]
# # Read image in Gray scale and check the dimension

# %%
img2=cv2.imread('/media/tumpa/Linux/Personal/Image Processing/image database/DIP3E_Original_Images_CH03/Fig0316(3)(third_from_top).tif',0)

# %%
img2.shape
# Out:
# (500, 500)

# %%
img1[100,10:0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 img1[100,100,:]
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
